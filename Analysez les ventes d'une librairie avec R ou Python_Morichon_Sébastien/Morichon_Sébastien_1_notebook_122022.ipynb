# %% [markdown]
# # <center> PROJET 6 - Analysez les ventes d'une librairie avec R ou Python</center>

# %% [markdown]
# <h3>Scénario</h3>
# <p>Vous êtes consultant Data Analyst chez Lapage, une grande librairie généraliste en ligne très réputée. Vous êtes directement rattaché au service Marketing.</p>
# <figure><a href="https://user.oc-static.com/upload/2020/11/23/16061367402655_Capture%20d%E2%80%99e%CC%81cran%202020-11-23%20a%CC%80%2014.05.04.png" class="oc-imageLink oc-imageLink--disabled"><img src="https://user.oc-static.com/upload/2020/11/23/16061367402655_Capture%20d%E2%80%99e%CC%81cran%202020-11-23%20a%CC%80%2014.05.04.png" alt="Logo de Lapage"></a>
# </figure>
# <p>Lapage était originellement une librairie physique avec plusieurs points de vente. Mais devant le succès de certains de ses produits et l’engouement de ses clients, elle a décidé depuis 2 ans d’ouvrir un site de vente en ligne. Vous intervenez car l’entreprise souhaite faire le point après deux ans d’exercice, et pouvoir analyser ses points forts, ses points faibles, les comportements clients, etc.</p>
# <p>L’équipe Marketing que vous intégrez se compose de&nbsp;:&nbsp;</p>
# <ul>
# <li>Annabelle, la responsable Marketing ;</li>
# <li>Julie, chargée d’études en marketing ;</li>
# <li>Antoine, chargé de produit marketing.</li>
# </ul>
# <p>Voici le mail de résumé envoyé par Annabelle, que vous trouvez dès votre arrivée&nbsp;:</p>
# <p>&nbsp;</p>
# <blockquote>
# <p><strong>Objet&nbsp;</strong>: Bienvenue dans l’équipe Marketing<strong><br>De</strong>&nbsp;: Annabelle<br><strong>À&nbsp;</strong>: Moi</p>
# <p>Hello,</p>
# <p>Bienvenue chez Lapage ! J’espère que tu te plairas parmi nous.</p>
# <p>Comme tu l’as certainement compris, nous avons ouvert il y a deux ans de cela notre librairie en ligne, et nous aimerions faire le point à présent. Cela nous permettra de décider de la marche à suivre, par exemple décider si nous devons créer certaines offres, adapter certains prix, etc.</p>
# <p>Cette analyse va être découpée en deux parties&nbsp;:</p>
# <ul>
# <li>Une analyse des différents indicateurs de vente, qui a été demandée directement par Antoine. Je t’ai mis en pièce jointe l’e-mail qu’il m’a envoyé résumant ses demandes.</li>
# <li>Une analyse plus ciblée sur les clients&nbsp;: l’objectif serait cette fois-ci de comprendre le comportement de nos clients en ligne, pour pouvoir ensuite comparer avec la connaissance acquise via nos librairies physiques. Pour cela, je t’invite à voir avec Julie, qui te précisera directement ses demandes à ce niveau.</li>
# </ul>
# <p>La base de données est en pièce jointe. N’hésite pas si tu as des questions, je me tiens à ta disposition.</p>
# <p>Excellente journée à toi&nbsp;!<br><strong>Annabelle</strong></p>
# <p><strong>Pièces jointes&nbsp;</strong>:</p>
# <ul>
# <li><strong><a href="https://s3.eu-west-1.amazonaws.com/course.oc-static.com/projects/DAN_V2_P6/Mail_Antoine_P3.pdf">Mail forwardé d’Antoine</a></strong></li>
# <li><strong><a href="https://s3-eu-west-1.amazonaws.com/static.oc-static.com/prod/courses/files/parcours-data-analyst/DAN-P6-donnees.zip">Fichier ZIP contenant les bases</a></strong></li>
# </ul>
# </blockquote>
# <p>&nbsp;</p>
# <p>Après avoir consulté le mail d’Antoine, vous prenez directement contact avec Julie.</p>
# <blockquote>
# <p>Hello Julie, je suis le nouveau Data Analyst chargé d’analyser les données de ventes en ligne. Annabelle m’a dit que tu avais des demandes concernant l’analyse des comportements clients.</p>
# <p><strong>Salut&nbsp;! Bienvenue dans l’équipe </strong><strong>🙂</strong><strong>&nbsp;J’allais justement prendre contact avec toi. C’est exactement cela&nbsp;! Je vais avoir besoin que tu regardes certaines corrélations, pour voir s’il n’y a pas certains points que nous pourrions analyser.</strong></p>
# <p>Bien sûr. Tu as déjà une idée précise de ce que tu veux que je regarde&nbsp;?</p>
# <p><strong>Oui&nbsp;! J’aimerais que tu regardes en particulier&nbsp;:&nbsp;</strong></p>
# <ul>
# <li><strong>le lien entre le genre d’un client et les catégories des livres achetés ;</strong></li>
# <li><strong>et ensuite le lien entre l’âge des clients et le montant total des achats, la fréquence d’achat, la taille du panier moyen et les catégories des livres achetés.</strong></li>
# </ul>
# <p>Ça marche, je m’occupe de ça&nbsp;!</p>
# </blockquote>
# <p>Vous gardez en tête toutes ces informations et commencez à regarder les données. 🕵️‍♂️</p>
# <aside data-claire-semantic="information">
# <p>Dans ce projet, vous êtes libre d’utiliser le langage de programmation de votre choix entre R et Python pour mener à bien votre analyse. Vous pouvez utiliser Jupyter (pour R et pour Python) ou R Markdown (pour R).&nbsp;</p>
# </aside>
# <h3>Livrables</h3>
# <ul>
# <li>Le ou les notebooks R Markdown ou Jupyter contenant les traitements et les différentes analyses effectués pour répondre aux demandes d’Antoine et Julie.</li>
# </ul>
# <aside data-claire-semantic="information">
# <p>Pour faciliter votre passage devant le jury, déposez sur la plateforme, dans un dossier zip nommé “<strong><em>Titre_du_projet_nom_prénom</em></strong>”,&nbsp;votre&nbsp;livrable nommé comme suit :&nbsp;<strong>Nom</strong>_<strong>Prénom</strong>_<strong>n° du livrable</strong>_<strong>nom du livrable</strong>_<strong>date de démarrage du projet</strong>. Cela donnera :&nbsp;</p>
# <ul>
# <li><em>Nom_Prénom_1_notebook_mmaaaa</em></li>
# </ul>
# <p>Par exemple, votre livrable peut être nommé comme suit&nbsp;<em>: Dupont_Jean_1_notebook</em>_<em>012022.</em></p>
# </aside>
# <h3>Soutenance</h3>
# <p>Durant la présentation orale, votre évaluateur jouera le rôle d’un des membres de votre équipe (Annabelle, Julie ou Antoine) à qui vous présentez vos résultats :</p>
# <ul>
# <li><strong>Présentation des livrables (15 minutes)</strong>
# <ul>
# <li>Détail du nettoyage des données&nbsp;: vous présenterez ici l’ensemble des choix et actions que vous avez réalisés afin d’obtenir un jeu de données exploitable.</li>
# <li>Restitution de l’analyse&nbsp;: les chiffres clés, KPI, graphiques générés, corrélations calculées, etc.</li>
# </ul>
# </li>
# <li><strong>Discussion (5 minutes)</strong>
# <ul>
# <li>L’évaluateur vous challengera sur&nbsp;vos choix.</li>
# </ul>
# </li>
# <li><strong>Debrief (5 minutes)</strong>
# <ul>
# <li>Votre évaluateur reprend son rôle de mentor pour que vous puissiez débriefer ensemble.</li>
# </ul>
# </li>
# </ul>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import datetime
import seaborn as sns
from scipy.stats import kruskal, spearmanr, ttest_ind, chi2_contingency, pearsonr, shapiro

# %%
clients = pd.read_csv("customers.csv")
produits = pd.read_csv("products.csv")
transactions = pd.read_csv("transactions.csv")

# %% [markdown]
# # 1 - Exploration de données

# %% [markdown]
# ## 1.1 - Clients

# %%
clients
# Out:
#      client_id sex  birth
# 0       c_4410   f   1967
# 1       c_7839   f   1975
# 2       c_1699   f   1984
# 3       c_5961   f   1962
# 4       c_5320   m   1943
# ...        ...  ..    ...
# 8618    c_7920   m   1956
# 8619    c_7403   f   1970
# 8620    c_5119   m   1974
# 8621    c_5643   f   1968
# 8622      c_84   f   1982
#
# [8623 rows x 3 columns]

# %%
# Affichage des informations comme le type de chaque variable
clients.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8623 entries, 0 to 8622
# Data columns (total 3 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   client_id  8623 non-null   object
#  1   sex        8623 non-null   object
#  2   birth      8623 non-null   int64
# dtypes: int64(1), object(2)
# memory usage: 202.2+ KB

# %%
# Affichage de certaines informations numérique
clients.describe(include="all")
# Out:
#        client_id   sex        birth
# count       8623  8623  8623.000000
# unique      8623     2          NaN
# top       c_4410     f          NaN
# freq           1  4491          NaN
# mean         NaN   NaN  1978.280877
# std          NaN   NaN    16.919535
# min          NaN   NaN  1929.000000
# 25%          NaN   NaN  1966.000000
# 50%          NaN   NaN  1979.000000
# 75%          NaN   NaN  1992.000000
# max          NaN   NaN  2004.000000

# %%
# Vérification des doublons de "client_id"
clients.duplicated("client_id").sum()
# Pas de doublons
# Out:
# 0

# %%
# Affichage du nombre de valeurs null
clients.isnull().sum()
# Pas de valeurs vide
# Out:
# client_id    0
# sex          0
# birth        0
# dtype: int64

# %%
# Création d'un tableau pour montrer la répartition moyenne du sexe des clients
sex = clients["sex"].value_counts().rename_axis('Femme/Homme').to_frame('sex').reset_index()
sex["Repartition"] = round((sex["sex"] / sex["sex"].sum())*100,2)
sex
#52.1% de Femmes vs 47.9% d'Hommes
# Out:
#   Femme/Homme   sex  Repartition
# 0           f  4491        52.08
# 1           m  4132        47.92

# %%
#Définition de l'année en cours pour calculer l'âge des clients
currentDateTime = datetime.datetime.now()
date = currentDateTime.date()
année = int(date.strftime("%Y"))
année
# Out:
# 2022

# %%
# Création de la variable "Âge"
clients["Âge"] = année - clients["birth"]
clients
# Out:
#      client_id sex  birth  Âge
# 0       c_4410   f   1967   55
# 1       c_7839   f   1975   47
# 2       c_1699   f   1984   38
# 3       c_5961   f   1962   60
# 4       c_5320   m   1943   79
# ...        ...  ..    ...  ...
# 8618    c_7920   m   1956   66
# 8619    c_7403   f   1970   52
# 8620    c_5119   m   1974   48
# 8621    c_5643   f   1968   54
# 8622      c_84   f   1982   40
#
# [8623 rows x 4 columns]

# %%
# Définition de l'âge moyen des Femmes et des Hommes
age_femme = clients.loc[clients["sex"]=="f"]["Âge"].mean()
age_homme = clients.loc[clients["sex"]=="m"]["Âge"].mean()
print("L'âge des Femmes moyen est de :", int(age_femme),"ans")
print("L'âge des Hommes moyen est de :", int(age_homme),"ans")
# Out:
# L'âge des Femmes moyen est de : 44 ans
# L'âge des Hommes moyen est de : 43 ans

# %%
#Création d'une table avec la répartition des âges en fonction du sexe du client
graph = clients.groupby("Âge")[["sex"]].value_counts()
graph = graph.to_frame().reset_index()
graph = graph.pivot(columns="sex", index="Âge")[[0]].reset_index()
graph
# Out:
#     Âge    0
# sex        f    m
# 0    18  232  208
# 1    19   65   81
# 2    20   66   80
# 3    21   72   57
# 4    22   78   58
# ..   ..  ...  ...
# 71   89    5    3
# 72   90    5    1
# 73   91    2    2
# 74   92    3    1
# 75   93    1    2
#
# [76 rows x 3 columns]

# %%
# Création du graphique représentant la répartition des âges en fonction du sexe du client
plt.figure(figsize=(10,6))
plt.plot(graph["Âge"], graph[0]["f"], label="Femme")
plt.plot(graph["Âge"], graph[0]["m"], label="Homme")
plt.legend()
# Outre le pic de client ayant 18 ans, le graphique ne montre rien de très significatif

# %%
# Affichage des clients ayant 18 ans
clients.loc[clients["Âge"]==18]
# Out:
#      client_id sex  birth  Âge
# 43      c_1046   m   2004   18
# 71      c_3081   m   2004   18
# 95      c_1418   f   2004   18
# 101     c_3338   m   2004   18
# 106     c_1774   f   2004   18
# ...        ...  ..    ...  ...
# 8584     c_461   f   2004   18
# 8594     c_294   m   2004   18
# 8598    c_5339   f   2004   18
# 8606    c_4077   m   2004   18
# 8615    c_2791   m   2004   18
#
# [440 rows x 4 columns]

# %% [markdown]
# ## 1.2 - Produits

# %%
produits
# Out:
#      id_prod   price  categ
# 0     0_1421   19.99      0
# 1     0_1368    5.13      0
# 2      0_731   17.99      0
# 3      1_587    4.99      1
# 4     0_1507    3.99      0
# ...      ...     ...    ...
# 3282    2_23  115.99      2
# 3283   0_146   17.14      0
# 3284   0_802   11.22      0
# 3285   1_140   38.56      1
# 3286  0_1920   25.16      0
#
# [3287 rows x 3 columns]

# %%
# Vérification des valeurs de la table
produits.describe()
# Price : Min -> -1€ et Max -> 300€
# Out:
#              price        categ
# count  3287.000000  3287.000000
# mean     21.856641     0.370246
# std      29.847908     0.615387
# min      -1.000000     0.000000
# 25%       6.990000     0.000000
# 50%      13.060000     0.000000
# 75%      22.990000     1.000000
# max     300.000000     2.000000

# %%
#Affichage des produits avec les valeurs minimales et maximales
produits.loc[(produits["price"]==produits["price"].min()) | (produits["price"]==produits["price"].max())]
# Le prix négatif semble être un produit test. D'où la référence à "T_0". La donnée sera supprimée lors du nettoyage
# Le prix à 300€ est possible, nous le laissons.
# Out:
#     id_prod  price  categ
# 731     T_0   -1.0      0
# 947     2_2  300.0      2

# %%
produits.isnull().sum()
# Pas de valeurs null
# Out:
# id_prod    0
# price      0
# categ      0
# dtype: int64

# %%
produits["id_prod"].duplicated().sum()
# Pas de doublons dans l'"id_produit"
# Out:
# 0

# %%
# Affichage du Boxplot pour voir les éventuelles valeurs abérantes 
plt.figure(figsize=(10,6))
plt.boxplot(produits["price"], vert=False)
plt.show()
# Ne nombreuses valeurs abérantes à partir de 50€

# %%
produits.loc[produits["price"]>50]
# Out:
#      id_prod   price  categ
# 10     2_228  225.17      2
# 11     1_178   51.92      1
# 38     2_100   72.11      2
# 64      2_89  107.99      2
# 73     2_225  157.99      2
# ...      ...     ...    ...
# 3267   2_101   63.99      2
# 3269   1_543   51.99      1
# 3271   2_123  147.99      2
# 3279   1_331   55.99      1
# 3282    2_23  115.99      2
#
# [273 rows x 3 columns]

# %%
# Affichage des différentes valeurs de la variable "categ"
produits["categ"].value_counts().reset_index()
# Out:
#    index  categ
# 0      0   2309
# 1      1    739
# 2      2    239

# %%
#Création du df qui va nous servir à afficher les références par catégorie
graph = produits.groupby("categ")[["id_prod"]].count().reset_index()

# Mise en forme Graphique
plt.figure(figsize=(10,6))
plt.bar(x=graph["categ"], height=graph["id_prod"])
plt.xticks(np.arange(min(graph["categ"]),max(graph["categ"])+1, step=1))
plt.title("Nombre de référence par catégorie")

values=graph["id_prod"].to_list()
for i in range(3):
    plt.text(i-0.1, values[i]+40, values[i])

plt.show()

# %% [markdown]
# ## 1.3 - Transcations

# %%
transactions
# Out:
#        id_prod                        date session_id client_id
# 0       0_1518  2022-05-20 13:21:29.043970   s_211425     c_103
# 1        1_251  2022-02-02 07:55:19.149409   s_158752    c_8534
# 2       0_1277  2022-06-18 15:44:33.155329   s_225667    c_6714
# 3        2_209  2021-06-24 04:19:29.835891    s_52962    c_6941
# 4       0_1509  2023-01-11 08:22:08.194479   s_325227    c_4232
# ...        ...                         ...        ...       ...
# 679527  0_1551  2022-01-15 13:05:06.246925   s_150195    c_8489
# 679528   1_639  2022-03-19 16:03:23.429229   s_181434    c_4370
# 679529  0_1425  2022-12-20 04:33:37.584749   s_314704     c_304
# 679530  0_1994  2021-07-16 20:36:35.350579    s_63204    c_2227
# 679531   1_523  2022-09-28 01:12:01.973763   s_274568    c_3873
#
# [679532 rows x 4 columns]

# %%
transactions.info()
# La variable "date" n'est pas au bon format
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 679532 entries, 0 to 679531
# Data columns (total 4 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   id_prod     679532 non-null  object
#  1   date        679532 non-null  object
#  2   session_id  679532 non-null  object
#  3   client_id   679532 non-null  object
# dtypes: object(4)
# memory usage: 20.7+ MB

# %%
#Vérification de la présence de doublons
transactions.duplicated().sum()
# 126 doublons présent
# Out:
# 126

# %%
# Affichage des doublons
transactions.loc[transactions.duplicated()==True]
# Out:
#        id_prod                             date session_id client_id
# 27778      T_0  test_2021-03-01 02:30:02.237437        s_0      ct_1
# 52424      T_0  test_2021-03-01 02:30:02.237419        s_0      ct_0
# 96687      T_0  test_2021-03-01 02:30:02.237412        s_0      ct_1
# 130188     T_0  test_2021-03-01 02:30:02.237419        s_0      ct_0
# 139339     T_0  test_2021-03-01 02:30:02.237443        s_0      ct_1
# ...        ...                              ...        ...       ...
# 653098     T_0  test_2021-03-01 02:30:02.237432        s_0      ct_0
# 657830     T_0  test_2021-03-01 02:30:02.237417        s_0      ct_0
# 662081     T_0  test_2021-03-01 02:30:02.237427        s_0      ct_1
# 671647     T_0  test_2021-03-01 02:30:02.237424        s_0      ct_1
# 679180     T_0  test_2021-03-01 02:30:02.237425        s_0      ct_1
#
# [126 rows x 4 columns]

# %%
# Affichage des différentes valeurs de la variable "client_id"
df = transactions.loc[transactions.duplicated()==True]
df["client_id"].value_counts()

# Deux clients différents, client 0 et 1. Equipe technique ?
# Out:
# ct_0    69
# ct_1    57
# Name: client_id, dtype: int64

# %%
# Affichage des différentes valeurs de la variable "session_id"
df = transactions.loc[transactions.duplicated()==True]
df["session_id"].value_counts()
# Out:
# s_0    126
# Name: session_id, dtype: int64

# %%
# Affichage des différentes valeurs de la variable "id_prod"
df = transactions.loc[transactions.duplicated()==True]
df["id_prod"].value_counts()

#Produit Test, les 126 entrées seront supprimés
# Les produits ont été commandés au même moment.
# Out:
# T_0    126
# Name: id_prod, dtype: int64

# %%
transactions.loc[transactions["id_prod"] == "T_0"]
# Out:
#        id_prod                             date session_id client_id
# 3019       T_0  test_2021-03-01 02:30:02.237419        s_0      ct_0
# 5138       T_0  test_2021-03-01 02:30:02.237425        s_0      ct_0
# 9668       T_0  test_2021-03-01 02:30:02.237437        s_0      ct_1
# 10728      T_0  test_2021-03-01 02:30:02.237436        s_0      ct_0
# 15292      T_0  test_2021-03-01 02:30:02.237430        s_0      ct_0
# ...        ...                              ...        ...       ...
# 657830     T_0  test_2021-03-01 02:30:02.237417        s_0      ct_0
# 662081     T_0  test_2021-03-01 02:30:02.237427        s_0      ct_1
# 670680     T_0  test_2021-03-01 02:30:02.237449        s_0      ct_1
# 671647     T_0  test_2021-03-01 02:30:02.237424        s_0      ct_1
# 679180     T_0  test_2021-03-01 02:30:02.237425        s_0      ct_1
#
# [200 rows x 4 columns]

# %%
#Suppression des lignes contenant "test" dans la variable date
transactions = transactions.loc[~transactions["date"].str.contains("test")]
transactions
# Out:
#        id_prod                        date session_id client_id
# 0       0_1518  2022-05-20 13:21:29.043970   s_211425     c_103
# 1        1_251  2022-02-02 07:55:19.149409   s_158752    c_8534
# 2       0_1277  2022-06-18 15:44:33.155329   s_225667    c_6714
# 3        2_209  2021-06-24 04:19:29.835891    s_52962    c_6941
# 4       0_1509  2023-01-11 08:22:08.194479   s_325227    c_4232
# ...        ...                         ...        ...       ...
# 679527  0_1551  2022-01-15 13:05:06.246925   s_150195    c_8489
# 679528   1_639  2022-03-19 16:03:23.429229   s_181434    c_4370
# 679529  0_1425  2022-12-20 04:33:37.584749   s_314704     c_304
# 679530  0_1994  2021-07-16 20:36:35.350579    s_63204    c_2227
# 679531   1_523  2022-09-28 01:12:01.973763   s_274568    c_3873
#
# [679332 rows x 4 columns]

# %%
# Vérification de la bonne supression des doublons
transactions.duplicated().sum()
# Il n'y a plus de doublons
# Out:
# 0

# %%
#Convertion du type date (object) vers un format DateTime (datetime64[ns]) 
transactions['date'] = pd.to_datetime(transactions['date'], errors = "coerce")
transactions
# Out:
# /var/folders/hy/g05wz4ln30z1r5z3mv1rwd2h0000gn/T/ipykernel_15405/2460749198.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   transactions['date'] = pd.to_datetime(transactions['date'], errors = "coerce")
#        id_prod                       date session_id client_id
# 0       0_1518 2022-05-20 13:21:29.043970   s_211425     c_103
# 1        1_251 2022-02-02 07:55:19.149409   s_158752    c_8534
# 2       0_1277 2022-06-18 15:44:33.155329   s_225667    c_6714
# 3        2_209 2021-06-24 04:19:29.835891    s_52962    c_6941
# 4       0_1509 2023-01-11 08:22:08.194479   s_325227    c_4232
# ...        ...                        ...        ...       ...
# 679527  0_1551 2022-01-15 13:05:06.246925   s_150195    c_8489
# ...

# %%
# Vérification de la bonne convertion du format
transactions.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 679332 entries, 0 to 679531
# Data columns (total 4 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   id_prod     679332 non-null  object
#  1   date        679332 non-null  datetime64[ns]
#  2   session_id  679332 non-null  object
#  3   client_id   679332 non-null  object
# dtypes: datetime64[ns](1), object(3)
# memory usage: 25.9+ MB

# %%
#Création des colonnes pour l'année, le mois et le jour
transactions["Année"] = transactions['date'].dt.strftime('%Y')
transactions["Mois"] = transactions['date'].dt.strftime('%m')
transactions["Jours"] = transactions['date'].dt.strftime('%d')
transactions
# Out:
# /var/folders/hy/g05wz4ln30z1r5z3mv1rwd2h0000gn/T/ipykernel_15405/4150240280.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   transactions["Année"] = transactions['date'].dt.strftime('%Y')
# /var/folders/hy/g05wz4ln30z1r5z3mv1rwd2h0000gn/T/ipykernel_15405/4150240280.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   transactions["Mois"] = transactions['date'].dt.strftime('%m')
# /var/folders/hy/g05wz4ln30z1r5z3mv1rwd2h0000gn/T/ipykernel_15405/4150240280.py:4: SettingWithCopyWarning:
# ...

# %%
# Affichage des différentes valeurs de la variable année
df = transactions["Année"].value_counts().to_frame().reset_index()
df["% des transactions"] = round(df["Année"]/df["Année"].sum(),3)*100
df = df.rename(columns={"index":"Année", "Année":"Nb de transactions", "% des transactions":"Répartition en %"})
df
# On constate qu'il existe une année 2023. On considére donc que nous sommes en 2023.
# Out:
#   Année  Nb de transactions  Répartition en %
# 0  2022              346500              51.0
# 1  2021              278335              41.0
# 2  2023               54497               8.0

# %%
# Affichage du graphique des répartitions des transactions
plt.figure(figsize=(10,6))
plt.pie(df["Nb de transactions"], labels=("2022", "2021","2023"), explode=(0.05, 0.05, 0.05), autopct="%.2f%%")
plt.title("Répartition des transactions entre 2021 et 2023")


plt.show()

# %% [markdown]
# # 2 - Nettoyage des données

# %% [markdown]
# ## 2.1 - Clients

# %%
clients
# Out:
#      client_id sex  birth  Âge
# 0       c_4410   f   1967   55
# 1       c_7839   f   1975   47
# 2       c_1699   f   1984   38
# 3       c_5961   f   1962   60
# 4       c_5320   m   1943   79
# ...        ...  ..    ...  ...
# 8618    c_7920   m   1956   66
# 8619    c_7403   f   1970   52
# 8620    c_5119   m   1974   48
# 8621    c_5643   f   1968   54
# 8622      c_84   f   1982   40
#
# [8623 rows x 4 columns]

# %%
# Suppression des clients "ct_O" et "ct_1" qui semble être des clients "test"
clients = clients.loc[(clients["client_id"]!="ct_0") & (clients["client_id"]!="ct_1")]
clients
# Out:
#      client_id sex  birth  Âge
# 0       c_4410   f   1967   55
# 1       c_7839   f   1975   47
# 2       c_1699   f   1984   38
# 3       c_5961   f   1962   60
# 4       c_5320   m   1943   79
# ...        ...  ..    ...  ...
# 8618    c_7920   m   1956   66
# 8619    c_7403   f   1970   52
# 8620    c_5119   m   1974   48
# 8621    c_5643   f   1968   54
# 8622      c_84   f   1982   40
#
# [8621 rows x 4 columns]

# %%
clients.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8621 entries, 0 to 8622
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   client_id  8621 non-null   object
#  1   sex        8621 non-null   object
#  2   birth      8621 non-null   int64
#  3   Âge        8621 non-null   int64
# dtypes: int64(2), object(2)
# memory usage: 336.8+ KB

# %%
clients.isnull().sum()
# Out:
# client_id    0
# sex          0
# birth        0
# Âge          0
# dtype: int64

# %% [markdown]
# ## 2.2 - Produits

# %%
produits
# Out:
#      id_prod   price  categ
# 0     0_1421   19.99      0
# 1     0_1368    5.13      0
# 2      0_731   17.99      0
# 3      1_587    4.99      1
# 4     0_1507    3.99      0
# ...      ...     ...    ...
# 3282    2_23  115.99      2
# 3283   0_146   17.14      0
# 3284   0_802   11.22      0
# 3285   1_140   38.56      1
# 3286  0_1920   25.16      0
#
# [3287 rows x 3 columns]

# %%
produits.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3287 entries, 0 to 3286
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   id_prod  3287 non-null   object
#  1   price    3287 non-null   float64
#  2   categ    3287 non-null   int64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 77.2+ KB

# %%
produits.isnull().sum()
# Out:
# id_prod    0
# price      0
# categ      0
# dtype: int64

# %%
# Suppression de la référence "T_0" à -1€. Produit test ? 
produits = produits.loc[produits["id_prod"]!="T_0"]
produits
# Out:
#      id_prod   price  categ
# 0     0_1421   19.99      0
# 1     0_1368    5.13      0
# 2      0_731   17.99      0
# 3      1_587    4.99      1
# 4     0_1507    3.99      0
# ...      ...     ...    ...
# 3282    2_23  115.99      2
# 3283   0_146   17.14      0
# 3284   0_802   11.22      0
# 3285   1_140   38.56      1
# 3286  0_1920   25.16      0
#
# [3286 rows x 3 columns]

# %% [markdown]
# ## 2.3 - Transactions

# %%
transactions
# Out:
#        id_prod                       date session_id client_id Année Mois  \
# 0       0_1518 2022-05-20 13:21:29.043970   s_211425     c_103  2022   05
# 1        1_251 2022-02-02 07:55:19.149409   s_158752    c_8534  2022   02
# 2       0_1277 2022-06-18 15:44:33.155329   s_225667    c_6714  2022   06
# 3        2_209 2021-06-24 04:19:29.835891    s_52962    c_6941  2021   06
# 4       0_1509 2023-01-11 08:22:08.194479   s_325227    c_4232  2023   01
# ...        ...                        ...        ...       ...   ...  ...
# 679527  0_1551 2022-01-15 13:05:06.246925   s_150195    c_8489  2022   01
# 679528   1_639 2022-03-19 16:03:23.429229   s_181434    c_4370  2022   03
# 679529  0_1425 2022-12-20 04:33:37.584749   s_314704     c_304  2022   12
# 679530  0_1994 2021-07-16 20:36:35.350579    s_63204    c_2227  2021   07
# 679531   1_523 2022-09-28 01:12:01.973763   s_274568    c_3873  2022   09
#
#        Jours
# 0         20
# 1         02
# 2         18
# 3         24
# ...

# %%
transactions.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 679332 entries, 0 to 679531
# Data columns (total 7 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   id_prod     679332 non-null  object
#  1   date        679332 non-null  datetime64[ns]
#  2   session_id  679332 non-null  object
#  3   client_id   679332 non-null  object
#  4   Année       679332 non-null  object
#  5   Mois        679332 non-null  object
#  6   Jours       679332 non-null  object
# dtypes: datetime64[ns](1), object(6)
# memory usage: 41.5+ MB

# %%
#Convertion object to int
transactions["Année"] = transactions["Année"].astype(int)
transactions["Mois"] = transactions["Mois"].astype(int)
transactions["Jours"] = transactions["Jours"].astype(int)
transactions.info()
# Out:
# /var/folders/hy/g05wz4ln30z1r5z3mv1rwd2h0000gn/T/ipykernel_15405/1149019650.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   transactions["Année"] = transactions["Année"].astype(int)
# /var/folders/hy/g05wz4ln30z1r5z3mv1rwd2h0000gn/T/ipykernel_15405/1149019650.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   transactions["Mois"] = transactions["Mois"].astype(int)
# /var/folders/hy/g05wz4ln30z1r5z3mv1rwd2h0000gn/T/ipykernel_15405/1149019650.py:4: SettingWithCopyWarning:
# ...

# %%
transactions.isnull().sum()
# Out:
# id_prod       0
# date          0
# session_id    0
# client_id     0
# Année         0
# Mois          0
# Jours         0
# dtype: int64

# %% [markdown]
# # 3 - Fusion des tables

# %%
# Lors de la fusion des tables, on s'apperçoit qu'avec le "join inner" entre df et produits, il manque des entrées. 
# Pour identifier les entrées qui manque, on fait un "join left".
df = pd.merge(clients, transactions, how="inner", on="client_id")
df = pd.merge(df, produits, how="left", on="id_prod")
df
# Out:
#        client_id sex  birth  Âge id_prod                       date  \
# 0         c_4410   f   1967   55  0_1316 2021-12-29 09:11:18.860592
# 1         c_4410   f   1967   55   1_385 2021-03-22 01:40:22.782925
# 2         c_4410   f   1967   55   1_190 2021-11-12 18:11:43.280574
# 3         c_4410   f   1967   55  0_1455 2021-03-22 14:29:25.189266
# 4         c_4410   f   1967   55   1_483 2022-03-13 21:35:55.949042
# ...          ...  ..    ...  ...     ...                        ...
# 679327      c_84   f   1982   40  0_1438 2022-05-29 06:11:50.316631
# 679328      c_84   f   1982   40  0_1020 2021-10-21 03:52:13.863959
# 679329      c_84   f   1982   40  0_1399 2021-10-01 16:13:18.997813
# 679330      c_84   f   1982   40  0_1417 2021-03-13 23:55:06.835238
# 679331      c_84   f   1982   40  0_1438 2022-03-29 06:11:50.316631
#
#        session_id  Année  Mois  Jours  price  categ
# 0        s_141762   2021    12     29   7.20    0.0
# ...

# %%
# On cherche quelles sont les lignes qui compose des entrées vides. 
df.loc[df["price"].isnull()==True]
# Out:
#        client_id sex  birth  Âge id_prod                       date  \
# 5372      c_4505   m   1976   46  0_2245 2022-01-09 09:23:31.000720
# 5395      c_4505   m   1976   46  0_2245 2022-11-09 09:23:31.000720
# 5968      c_3468   f   1981   41  0_2245 2021-09-11 10:52:05.205583
# 5974      c_3468   f   1981   41  0_2245 2022-05-11 10:52:05.205583
# 13435     c_1403   f   1978   44  0_2245 2022-09-15 14:26:50.187952
# ...          ...  ..    ...  ...     ...                        ...
# 666137    c_4283   f   1976   46  0_2245 2022-08-01 02:46:38.931757
# 666215    c_4283   f   1976   46  0_2245 2021-09-01 02:46:38.931757
# 671790    c_6236   f   1976   46  0_2245 2022-02-25 00:08:08.736068
# 677275    c_4453   m   1981   41  0_2245 2022-02-16 11:35:20.319501
# 677367    c_4453   m   1981   41  0_2245 2022-05-16 11:35:20.319501
#
#        session_id  Année  Mois  Jours  price  categ
# 5372     s_147220   2022     1      9    NaN    NaN
# ...

# %%
# On vérifie quelles sont les occurences "id_produits"
df.loc[df["price"].isnull()==True]["id_prod"].value_counts()
# Seule la référence "0_2245" ne comporte pas de prix.
# Out:
# 0_2245    221
# Name: id_prod, dtype: int64

# %%
# On vérifie si cette référence est présente dans la table "produits"
produits.loc[produits["id_prod"]=="0_2245"]
# La référence n'est pas présente. On va reconstituer la données.
# Out:
# Empty DataFrame
# Columns: [id_prod, price, categ]
# Index: []

# %%
df.loc[df["id_prod"]=="0_2245"]
# Out:
#        client_id sex  birth  Âge id_prod                       date  \
# 5372      c_4505   m   1976   46  0_2245 2022-01-09 09:23:31.000720
# 5395      c_4505   m   1976   46  0_2245 2022-11-09 09:23:31.000720
# 5968      c_3468   f   1981   41  0_2245 2021-09-11 10:52:05.205583
# 5974      c_3468   f   1981   41  0_2245 2022-05-11 10:52:05.205583
# 13435     c_1403   f   1978   44  0_2245 2022-09-15 14:26:50.187952
# ...          ...  ..    ...  ...     ...                        ...
# 666137    c_4283   f   1976   46  0_2245 2022-08-01 02:46:38.931757
# 666215    c_4283   f   1976   46  0_2245 2021-09-01 02:46:38.931757
# 671790    c_6236   f   1976   46  0_2245 2022-02-25 00:08:08.736068
# 677275    c_4453   m   1981   41  0_2245 2022-02-16 11:35:20.319501
# 677367    c_4453   m   1981   41  0_2245 2022-05-16 11:35:20.319501
#
#        session_id  Année  Mois  Jours  price  categ
# 5372     s_147220   2022     1      9    NaN    NaN
# ...

# %%
# Ajout de la référence 0 dans "categ" pour le produit 0_2245
mask = df["id_prod"]=="0_2245"
df.loc[mask, 'categ'] = 0
df.loc[df["id_prod"]=="0_2245"]
# Out:
#        client_id sex  birth  Âge id_prod                       date  \
# 5372      c_4505   m   1976   46  0_2245 2022-01-09 09:23:31.000720
# 5395      c_4505   m   1976   46  0_2245 2022-11-09 09:23:31.000720
# 5968      c_3468   f   1981   41  0_2245 2021-09-11 10:52:05.205583
# 5974      c_3468   f   1981   41  0_2245 2022-05-11 10:52:05.205583
# 13435     c_1403   f   1978   44  0_2245 2022-09-15 14:26:50.187952
# ...          ...  ..    ...  ...     ...                        ...
# 666137    c_4283   f   1976   46  0_2245 2022-08-01 02:46:38.931757
# 666215    c_4283   f   1976   46  0_2245 2021-09-01 02:46:38.931757
# 671790    c_6236   f   1976   46  0_2245 2022-02-25 00:08:08.736068
# 677275    c_4453   m   1981   41  0_2245 2022-02-16 11:35:20.319501
# 677367    c_4453   m   1981   41  0_2245 2022-05-16 11:35:20.319501
#
#        session_id  Année  Mois  Jours  price  categ
# 5372     s_147220   2022     1      9    NaN    0.0
# ...

# %%
# Vérification
df.isnull().sum()
# Out:
# client_id       0
# sex             0
# birth           0
# Âge             0
# id_prod         0
# date            0
# session_id      0
# Année           0
# Mois            0
# Jours           0
# price         221
# categ           0
# dtype: int64

# %% [markdown]
# #### Ajout du prix pour la référence 0_2245

# %%
# On calcule la moyenne des prix de la catégorie 0
moyenne_0 = round(df.loc[df["categ"] == 0]["price"].mean(),2)
moyenne_0
# Out:
# 10.64

# %%
#On ajoute le prix calculé au produit 0_2245
mask = df["id_prod"]=="0_2245"
df.loc[mask, 'price'] = moyenne_0
df.loc[df["id_prod"]=="0_2245"]
# Out:
#        client_id sex  birth  Âge id_prod                       date  \
# 5372      c_4505   m   1976   46  0_2245 2022-01-09 09:23:31.000720
# 5395      c_4505   m   1976   46  0_2245 2022-11-09 09:23:31.000720
# 5968      c_3468   f   1981   41  0_2245 2021-09-11 10:52:05.205583
# 5974      c_3468   f   1981   41  0_2245 2022-05-11 10:52:05.205583
# 13435     c_1403   f   1978   44  0_2245 2022-09-15 14:26:50.187952
# ...          ...  ..    ...  ...     ...                        ...
# 666137    c_4283   f   1976   46  0_2245 2022-08-01 02:46:38.931757
# 666215    c_4283   f   1976   46  0_2245 2021-09-01 02:46:38.931757
# 671790    c_6236   f   1976   46  0_2245 2022-02-25 00:08:08.736068
# 677275    c_4453   m   1981   41  0_2245 2022-02-16 11:35:20.319501
# 677367    c_4453   m   1981   41  0_2245 2022-05-16 11:35:20.319501
#
#        session_id  Année  Mois  Jours  price  categ
# 5372     s_147220   2022     1      9  10.64    0.0
# ...

# %% [markdown]
# # -----------------------------------------------------------------------------------------

# %% [markdown]
# ### Nous allons ajouter quelques colonnes pour approndir l'analyse
# - Date Fixe
# - Nombre de vente total par client (en nombre)
# - Nombre de vente mensuelle (nombre de vente / 23) on retire le mois d'octobre
# - Nombre de vente total par client - CA (en €)
# - Panier moyen (en nombre)
# - Panier moyen (en €)

# %%
#Mise en forme de la date au format (AAAA-MM-DD)
df['date_fixe'] = df['date'].dt.date
df
# Out:
#        client_id sex  birth  Âge id_prod                       date  \
# 0         c_4410   f   1967   55  0_1316 2021-12-29 09:11:18.860592
# 1         c_4410   f   1967   55   1_385 2021-03-22 01:40:22.782925
# 2         c_4410   f   1967   55   1_190 2021-11-12 18:11:43.280574
# 3         c_4410   f   1967   55  0_1455 2021-03-22 14:29:25.189266
# 4         c_4410   f   1967   55   1_483 2022-03-13 21:35:55.949042
# ...          ...  ..    ...  ...     ...                        ...
# 679327      c_84   f   1982   40  0_1438 2022-05-29 06:11:50.316631
# 679328      c_84   f   1982   40  0_1020 2021-10-21 03:52:13.863959
# 679329      c_84   f   1982   40  0_1399 2021-10-01 16:13:18.997813
# 679330      c_84   f   1982   40  0_1417 2021-03-13 23:55:06.835238
# 679331      c_84   f   1982   40  0_1438 2022-03-29 06:11:50.316631
#
#        session_id  Année  Mois  Jours  price  categ   date_fixe
# 0        s_141762   2021    12     29   7.20    0.0  2021-12-29
# ...

# %%
# Ajout du nombre d'achat total par client
df = df.merge(
    df.groupby('client_id').count()['date'].reset_index(),
    how="left",on="client_id")
df = df.rename(columns={"date_y":"vente_total","date_x":"date"})
df
# Out:
#        client_id sex  birth  Âge id_prod                       date  \
# 0         c_4410   f   1967   55  0_1316 2021-12-29 09:11:18.860592
# 1         c_4410   f   1967   55   1_385 2021-03-22 01:40:22.782925
# 2         c_4410   f   1967   55   1_190 2021-11-12 18:11:43.280574
# 3         c_4410   f   1967   55  0_1455 2021-03-22 14:29:25.189266
# 4         c_4410   f   1967   55   1_483 2022-03-13 21:35:55.949042
# ...          ...  ..    ...  ...     ...                        ...
# 679327      c_84   f   1982   40  0_1438 2022-05-29 06:11:50.316631
# 679328      c_84   f   1982   40  0_1020 2021-10-21 03:52:13.863959
# 679329      c_84   f   1982   40  0_1399 2021-10-01 16:13:18.997813
# 679330      c_84   f   1982   40  0_1417 2021-03-13 23:55:06.835238
# 679331      c_84   f   1982   40  0_1438 2022-03-29 06:11:50.316631
#
#        session_id  Année  Mois  Jours  price  categ   date_fixe  vente_total
# ...

# %%
#Ajout d'une colonne avec le nombre de vente mensuel moyen
df["vente_mensuelle"] = df["vente_total"] / 23 #(23 mois car 2ans - le mois d'octobre 2021)
df
# Out:
#        client_id sex  birth  Âge id_prod                       date  \
# 0         c_4410   f   1967   55  0_1316 2021-12-29 09:11:18.860592
# 1         c_4410   f   1967   55   1_385 2021-03-22 01:40:22.782925
# 2         c_4410   f   1967   55   1_190 2021-11-12 18:11:43.280574
# 3         c_4410   f   1967   55  0_1455 2021-03-22 14:29:25.189266
# 4         c_4410   f   1967   55   1_483 2022-03-13 21:35:55.949042
# ...          ...  ..    ...  ...     ...                        ...
# 679327      c_84   f   1982   40  0_1438 2022-05-29 06:11:50.316631
# 679328      c_84   f   1982   40  0_1020 2021-10-21 03:52:13.863959
# 679329      c_84   f   1982   40  0_1399 2021-10-01 16:13:18.997813
# 679330      c_84   f   1982   40  0_1417 2021-03-13 23:55:06.835238
# 679331      c_84   f   1982   40  0_1438 2022-03-29 06:11:50.316631
#
#        session_id  Année  Mois  Jours  price  categ   date_fixe  vente_total  \
# ...

# %%
#Ajout d'une colonne contenant le total de CA réalisé par chaque client
df = df.merge(
    df.groupby('client_id').sum()['price'].reset_index(),
    how="left",on="client_id")
df = df.rename(columns={"price_x":"price","price_y":"Total_CA"})
df
# Out:
#        client_id sex  birth  Âge id_prod                       date  \
# 0         c_4410   f   1967   55  0_1316 2021-12-29 09:11:18.860592
# 1         c_4410   f   1967   55   1_385 2021-03-22 01:40:22.782925
# 2         c_4410   f   1967   55   1_190 2021-11-12 18:11:43.280574
# 3         c_4410   f   1967   55  0_1455 2021-03-22 14:29:25.189266
# 4         c_4410   f   1967   55   1_483 2022-03-13 21:35:55.949042
# ...          ...  ..    ...  ...     ...                        ...
# 679327      c_84   f   1982   40  0_1438 2022-05-29 06:11:50.316631
# 679328      c_84   f   1982   40  0_1020 2021-10-21 03:52:13.863959
# 679329      c_84   f   1982   40  0_1399 2021-10-01 16:13:18.997813
# 679330      c_84   f   1982   40  0_1417 2021-03-13 23:55:06.835238
# 679331      c_84   f   1982   40  0_1438 2022-03-29 06:11:50.316631
#
#        session_id  Année  Mois  Jours  price  categ   date_fixe  vente_total  \
# ...

# %%
#Ajout d'une colonne avce le panier moyen
df["panier_moyen_€"] = df["Total_CA"] / df["vente_total"]
df
# Out:
#        client_id sex  birth  Âge id_prod                       date  \
# 0         c_4410   f   1967   55  0_1316 2021-12-29 09:11:18.860592
# 1         c_4410   f   1967   55   1_385 2021-03-22 01:40:22.782925
# 2         c_4410   f   1967   55   1_190 2021-11-12 18:11:43.280574
# 3         c_4410   f   1967   55  0_1455 2021-03-22 14:29:25.189266
# 4         c_4410   f   1967   55   1_483 2022-03-13 21:35:55.949042
# ...          ...  ..    ...  ...     ...                        ...
# 679327      c_84   f   1982   40  0_1438 2022-05-29 06:11:50.316631
# 679328      c_84   f   1982   40  0_1020 2021-10-21 03:52:13.863959
# 679329      c_84   f   1982   40  0_1399 2021-10-01 16:13:18.997813
# 679330      c_84   f   1982   40  0_1417 2021-03-13 23:55:06.835238
# 679331      c_84   f   1982   40  0_1438 2022-03-29 06:11:50.316631
#
#        session_id  Année  Mois  Jours  price  categ   date_fixe  vente_total  \
# ...

# %%
#Ajout d'une colonne avec les différentes classes d'âge
df['classe_age'] = '18-30'
df['classe_age'].loc[df[df['Âge']>=30].index] = '30-40'
df['classe_age'].loc[df[df['Âge']>=40].index] = '40-50'
df['classe_age'].loc[df[df['Âge']>=50].index] = '50-60'
df['classe_age'].loc[df[df['Âge']>=60].index] = '60-70'
df['classe_age'].loc[df[df['Âge']>=70].index] = '70-80'
df['classe_age'].loc[df[df['Âge']>=80].index] = '>80'
# Out:
# /var/folders/hy/g05wz4ln30z1r5z3mv1rwd2h0000gn/T/ipykernel_15405/1570921058.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['classe_age'].loc[df[df['Âge']>=30].index] = '30-40'
# /var/folders/hy/g05wz4ln30z1r5z3mv1rwd2h0000gn/T/ipykernel_15405/1570921058.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['classe_age'].loc[df[df['Âge']>=40].index] = '40-50'
# /var/folders/hy/g05wz4ln30z1r5z3mv1rwd2h0000gn/T/ipykernel_15405/1570921058.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %%
df
# Out:
#        client_id sex  birth  Âge id_prod                       date  \
# 0         c_4410   f   1967   55  0_1316 2021-12-29 09:11:18.860592
# 1         c_4410   f   1967   55   1_385 2021-03-22 01:40:22.782925
# 2         c_4410   f   1967   55   1_190 2021-11-12 18:11:43.280574
# 3         c_4410   f   1967   55  0_1455 2021-03-22 14:29:25.189266
# 4         c_4410   f   1967   55   1_483 2022-03-13 21:35:55.949042
# ...          ...  ..    ...  ...     ...                        ...
# 679327      c_84   f   1982   40  0_1438 2022-05-29 06:11:50.316631
# 679328      c_84   f   1982   40  0_1020 2021-10-21 03:52:13.863959
# 679329      c_84   f   1982   40  0_1399 2021-10-01 16:13:18.997813
# 679330      c_84   f   1982   40  0_1417 2021-03-13 23:55:06.835238
# 679331      c_84   f   1982   40  0_1438 2022-03-29 06:11:50.316631
#
#        session_id  Année  Mois  Jours  price  categ   date_fixe  vente_total  \
# ...

# %% [markdown]
# # <center>ANALYSE</center>

# %%
#Affichons le total du CA au cours des deux dernières année
df_mois = df.groupby(pd.Grouper(key='date', freq='M')).sum().reset_index()
df_mois = df_mois[["date", "Total_CA"]]


plt.figure(figsize=(10,6))
df_mois.plot(x='date', y='Total_CA')

plt.title("Représentation des ventes par mois")
plt.legend()
plt.xlabel("Date")
plt.ylabel("Total des ventes en K€")

plt.show()

# %% [markdown]
# On constate un pic au niveau du mois d'octobre. Vérifions d'où cela peut provenir

# %% [markdown]
# Commençons d'abord par jeter un oeil au nombre de vente par catéghorie de livre

# %%
plt.figure(figsize=(15,10))
sns.histplot(df, x="date", hue="categ", palette=["#c4f1ff", "#76deff", "#00b3eb"])
plt.title("Nombre de vente par catégorie")
plt.xlabel("Date")
plt.ylabel("Nombre de vente")


plt.show()

# %% [markdown]
# Dans le graphique ci-dessous, nous pouvons remarquer l'absence de donnée pour la catégorie 1 proche du mois d'octobre 2021. Nous allons donc vérrifier cela.

# %%
#Affichage des différents jours référencés au mois d'octobre 2022.
temp_Df = df.loc[(df.Année == 2021) & (df.Mois == 10) & (df.categ==1)].sort_values("Jours")
temp_Df.Jours.unique()
# Out:
# array([ 1, 28, 29, 30, 31])

# %% [markdown]
# Nous pouvons contastater ici que pour le mois d'Octobre, nous ne possédons que les données pour les jours suivants : 1,28,29,30 et 31. Il nous manque donc près 1'un mois de données.

# %% [markdown]
# Pour avoir une analyse équitable, nous ne prendrons pas en compte de mois d'octobre dans nos futurs test statistique

# %%
#On selectionne toutes les lignes comprises au mois d'octobre 2022 pour ensuite les supprimer.  
octobre = df.loc[(df["date"]>='2021-10-01') & (df["date"]<='2021-10-31')]
df.drop(octobre.index, inplace=True)
df
# Out:
#        client_id sex  birth  Âge id_prod                       date  \
# 0         c_4410   f   1967   55  0_1316 2021-12-29 09:11:18.860592
# 1         c_4410   f   1967   55   1_385 2021-03-22 01:40:22.782925
# 2         c_4410   f   1967   55   1_190 2021-11-12 18:11:43.280574
# 3         c_4410   f   1967   55  0_1455 2021-03-22 14:29:25.189266
# 4         c_4410   f   1967   55   1_483 2022-03-13 21:35:55.949042
# ...          ...  ..    ...  ...     ...                        ...
# 679325      c_84   f   1982   40   1_459 2022-02-17 00:16:56.629536
# 679326      c_84   f   1982   40  0_1452 2021-09-20 10:11:35.510099
# 679327      c_84   f   1982   40  0_1438 2022-05-29 06:11:50.316631
# 679330      c_84   f   1982   40  0_1417 2021-03-13 23:55:06.835238
# 679331      c_84   f   1982   40  0_1438 2022-03-29 06:11:50.316631
#
#        session_id  Année  Mois  Jours  price  categ   date_fixe  vente_total  \
# ...

# %%
#Affichage du nombre de vente par catégorie
plt.figure(figsize=(15,10))
sns.histplot(df, x="date", hue="categ", palette=["#c4f1ff", "#76deff", "#00b3eb"])
plt.title("Nombre de vente par catégorie")
plt.xlabel("Date")
plt.ylabel("Nombre de vente")


plt.show()

# %% [markdown]
# ### Concentrons nous maintenant sur nos clients

# %%
#Affichage du Top 6 de nos clients
top6 = df.pivot_table(
    index="client_id", 
    values=["categ","Total_CA","vente_total", "vente_mensuelle"]).reset_index().sort_values("vente_total", ascending=False).head(6)
top6
# Out:
#      client_id   Total_CA     categ  vente_mensuelle  vente_total
# 677     c_1609  324033.35  0.216584      1108.173913        25488
# 6336    c_6714  153662.76  0.463231       399.434783         9187
# 2723    c_3454  113669.85  0.612860       294.478261         6773
# 4387    c_4958  289760.34  1.630887       225.869565         5195
# 2513    c_3263    5276.87  0.227041        17.521739          403
# 1268    c_2140    5208.82  0.238845        17.478261          402

# %%
#On ajoute une colonne avec B2C pour tous les clients
df["type_client"] = "B2C"

# %%
#On selectionne nos plus gros clients (4) pour changer la catégorie à B2B
df["type_client"].loc[df["client_id"].isin(top6["client_id"].head(4))] = "B2B"
# Out:
# /var/folders/hy/g05wz4ln30z1r5z3mv1rwd2h0000gn/T/ipykernel_15405/2674584228.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["type_client"].loc[df["client_id"].isin(top6["client_id"].head(4))] = "B2B"

# %%
#On créer deux tables B2B et B2C
B2B = df.loc[df["type_client"]=="B2B"]
B2C = df.loc[df["type_client"]=="B2C"]

# %%
#Affichage de la table B2B avec les clients
B2B.pivot_table(index="client_id").reset_index()
# Out:
#   client_id        Année      Jours      Mois   Total_CA  birth     categ  \
# 0    c_1609  2021.680126  15.889646  6.459541  324033.35   1980  0.216584
# 1    c_3454  2021.706972  15.543894  6.405812  113669.85   1969  0.612860
# 2    c_4958  2021.695644  15.582418  6.331633  289760.34   1999  1.630887
# 3    c_6714  2021.695857  15.368474  6.388908  153662.76   1968  0.463231
#
#    panier_moyen_€      price  vente_mensuelle  vente_total  Âge
# 0       12.713173  12.780474      1108.173913        25488   42
# 1       16.782792  16.850336       294.478261         6773   53
# 2       55.776774  55.525895       225.869565         5195   23
# 3       16.726109  16.833816       399.434783         9187   54

# %%
#Affichage graphique des clients B2B, on regarde leurs achats par catégorie
plt.figure(figsize=(10,6))
sns.countplot(data=B2B, x="client_id", hue="categ")

plt.title("Répartition des achats par catégorie pour les clients B2B")
plt.xlabel("Identifiant du client")
plt.ylabel("Nombre de vente")

plt.show()

# %% [markdown]
# On constate sur ce graphique que la répartition par catégorie est inégalitaire.

# %%
#Affichage des graphiques catégorie en fonction de la date pour les 4 clients B2B.

for i in B2B["client_id"].unique():
    plt.figure(figsize=(10,6))
    print("Client :",i)
    plt.title("Répartition des ventes par catégorie.")
    sns.histplot(data=B2B[B2B["client_id"]==i], x="date", hue="categ", binwidth=7)
    plt.show()
# Out:
# Client : c_4958
# Client : c_6714
# Client : c_1609
# Client : c_3454

# %%
# HeatMap Triangle de corrélation sur l'ensemble des données
mask = np.triu(np.ones_like(df.corr()))
plt.figure(figsize=(10,6))
sns.heatmap(data=df.corr(), mask = mask, annot=True, cmap='BrBG')
plt.show()

# %%
#HeatMap Triangle de corrélation sur les données B2B
mask = np.triu(np.ones_like(B2B.corr()))
plt.figure(figsize=(10,6))
sns.heatmap(data=B2B.corr(), mask = mask, annot=True, cmap='BrBG')
plt.show()

# %%
#Affichage de la densité d'achat des catégories en fonction de l'âge des clients (B2C)
plt.figure(figsize=(10,6))
sns.displot(data=B2C,x="Âge", hue="categ", kind="kde", fill=True)
plt.show()

# %%
# Affichage d'un boxplot indiquant la variation du prix d'achat en fonction des tranches d'âge des clients
sns.boxplot(data=df.sort_values("classe_age"), y="classe_age", x="price", showfliers=False)
# Out:
# <AxesSubplot:xlabel='price', ylabel='classe_age'>

# %%
#Affichage du total du CA en fonction de l'âge
plt.figure(figsize=(10,6))
sns.scatterplot(data=B2C.sample(100), x="Âge", y="Total_CA",hue="classe_age", s=100)
plt.grid(axis="both")

# %%
# Affichage des ventes totales en fonction de l'âge
plt.figure(figsize=(15,6))
sns.boxplot(data=B2C.pivot_table(index="client_id"), x="Âge", y="vente_total", fliersize=False)
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ### Affichage des Top et Flop

# %%
classement = B2C.pivot_table(values="client_id", index="id_prod",aggfunc="count")
TOP10 = classement.sort_values("client_id", ascending=False).head(10)
FLOP10 = classement.sort_values("client_id", ascending=False).tail(10)

# %%
TOP10
# Out:
#          client_id
# id_prod
# 1_369         2110
# 1_414         2038
# 1_417         2034
# 1_498         1962
# 1_425         1954
# 1_412         1846
# 1_413         1835
# 1_407         1808
# 1_406         1800
# 1_403         1790

# %%
FLOP10
# Out:
#          client_id
# id_prod
# 0_541            1
# 0_1151           1
# 0_1533           1
# 0_1284           1
# 2_66             1
# 0_1498           1
# 0_680            1
# 0_886            1
# 0_833            1
# 0_1601           1

# %% [markdown]
# ## <center>Tests Statistiques</center>

# %% [markdown]
# ## GENRE

# %% [markdown]
# ### Analyse deux variables qualitatives avec Chi2

# %% [markdown]
# Variable Genre et Catégorie

# %%
df
# Out:
#        client_id sex  birth  Âge id_prod                       date  \
# 0         c_4410   f   1967   55  0_1316 2021-12-29 09:11:18.860592
# 1         c_4410   f   1967   55   1_385 2021-03-22 01:40:22.782925
# 2         c_4410   f   1967   55   1_190 2021-11-12 18:11:43.280574
# 3         c_4410   f   1967   55  0_1455 2021-03-22 14:29:25.189266
# 4         c_4410   f   1967   55   1_483 2022-03-13 21:35:55.949042
# ...          ...  ..    ...  ...     ...                        ...
# 679325      c_84   f   1982   40   1_459 2022-02-17 00:16:56.629536
# 679326      c_84   f   1982   40  0_1452 2021-09-20 10:11:35.510099
# 679327      c_84   f   1982   40  0_1438 2022-05-29 06:11:50.316631
# 679330      c_84   f   1982   40  0_1417 2021-03-13 23:55:06.835238
# 679331      c_84   f   1982   40  0_1438 2022-03-29 06:11:50.316631
#
#        session_id  Année  Mois  Jours  price  categ   date_fixe  vente_total  \
# ...

# %%
# Tableau de contingence 
cont_total = B2C[["sex", "categ"]].pivot_table(index="categ", columns="sex", aggfunc=len, margins=True, margins_name="TOTAL")
cont = B2C[["sex", "categ"]].pivot_table(index="categ", columns="sex", aggfunc=len, margins=False, margins_name="TOTAL")
cont_total
# Out:
# sex         f       m   TOTAL
# categ
# 0.0    192311  178293  370604
# 1.0    110718  100387  211105
# 2.0     16453   15364   31817
# TOTAL  319482  294044  613526

# %%
#Heatmap du tableau de contingence
sns.heatmap(cont)
# Out:
# <AxesSubplot:xlabel='sex', ylabel='categ'>

# %%
sample_df = B2C.sample(1500)
table = pd.crosstab(sample_df['categ'], sample_df['sex'], margins=False)
stat, p, dof, expected = chi2_contingency(table)
stat, p, dof, expected

if (p>0.05):
    print("La p-value est égale à:",round(p,2))
    print("l'Hypothèse H0 est donc retenu.\nIl n'existe pas de dépendance entre le genre du client et les catégories de livre achetés")
else:
    print("La p-value est égale à:",round(p,2))
    print("l'Hypothèse H1 est donc retenu.\nIl existe une dépendance entre le genre du client et les catégories de livre achetés")
# Out:
# La p-value est égale à: 0.62
# l'Hypothèse H0 est donc retenu.
# Il n'existe pas de dépendance entre le genre du client et les catégories de livre achetés

# %% [markdown]
# ## Lien entre âge et montant total des achats

# %%
B2C.head()
# Out:
#   client_id sex  birth  Âge id_prod                       date session_id  \
# 0    c_4410   f   1967   55  0_1316 2021-12-29 09:11:18.860592   s_141762
# 1    c_4410   f   1967   55   1_385 2021-03-22 01:40:22.782925     s_9707
# 2    c_4410   f   1967   55   1_190 2021-11-12 18:11:43.280574   s_118628
# 3    c_4410   f   1967   55  0_1455 2021-03-22 14:29:25.189266     s_9942
# 4    c_4410   f   1967   55   1_483 2022-03-13 21:35:55.949042   s_178686
#
#    Année  Mois  Jours  price  categ   date_fixe  vente_total  vente_mensuelle  \
# 0   2021    12     29   7.20    0.0  2021-12-29           76         3.304348
# 1   2021     3     22  25.99    1.0  2021-03-22           76         3.304348
# 2   2021    11     12  14.53    1.0  2021-11-12           76         3.304348
# 3   2021     3     22   8.99    0.0  2021-03-22           76         3.304348
# 4   2022     3     13  15.99    1.0  2022-03-13           76         3.304348
#
#    Total_CA  panier_moyen_€ classe_age type_client
# ...

# %%
sns.scatterplot(data=B2C, x="Âge", y="Total_CA")
# Out:
# <AxesSubplot:xlabel='Âge', ylabel='Total_CA'>

# %%
sample_df = B2C.sample(1500)
corr, p = pearsonr(sample_df["Âge"], sample_df["Total_CA"])

if p>0.05:
    print("H0 : La variables Âge et Total_CA sont indépendantes")
    print("p-value :",p)
    print("Corrélation :", corr)
else:
    print("H1 : Les variables Âge et Total_CA ne sont pas indépendantes")
    print("p-value :",p)
    print("Corrélation :", corr)
# Out:
# H1 : Les variables Âge et Total_CA ne sont pas indépendantes
# p-value : 2.162265459434914e-13
# Corrélation : -0.18794149430701473

# %% [markdown]
# La corrélation est négative (-0.2) comme nous pouvons le voir sur le graphique ci-dessous.
# Nous pouvons en conclure que plus l'âge augmente, plus le CA_total baisse.

# %% [markdown]
# ## Lien entre âge et fréquence d'achat

# %%
sns.scatterplot(data=B2C, x="Âge", y="vente_mensuelle")
# Out:
# <AxesSubplot:xlabel='Âge', ylabel='vente_mensuelle'>

# %%
sample_df = B2C.sample(1500)
corr, p = pearsonr(sample_df["Âge"], sample_df["vente_mensuelle"])

if p>0.05:
    print("H0 : La variables Âge et Fréquence d'achat sont indépendantes")
    print("p-value :",p)
    print("Corrélation :", corr)
else:
    print("H1 : Les variables Âge et Fréquence d'achat ne sont pas indépendantes")
    print("p-value :",p)
    print("Corrélation :", corr)
# Out:
# H1 : Les variables Âge et Fréquence d'achat ne sont pas indépendantes
# p-value : 5.709249837997564e-05
# Corrélation : -0.10371867480111846

# %% [markdown]
# La corrélation entre les deux variables est négative comme nous pouvons le voir sur le graphique ci-dessous.
# Nous pouvons en conclure que plus l'âge augmente, plus la fréquence d'achat baisse.
#
# Nous pouvons également constaté que la fréquence d'achat augmente fortement entre les clients des classes d'âge 18-30 vs 31-50 et baisse progressivement par la suite.

# %% [markdown]
# ## Lien entre âge et taille du panier moyen

# %%
sns.scatterplot(data=B2C, x="Âge", y="panier_moyen_€")
# Out:
# <AxesSubplot:xlabel='Âge', ylabel='panier_moyen_€'>

# %%
sample_df = B2C.sample(1500)
corr, p = pearsonr(sample_df["Âge"], sample_df["panier_moyen_€"])

if p>0.05:
    print("H0 : La variables Âge et panier moyen sont indépendants")
    print("p-value :",p)
    print("Corrélation :", corr)
else:
    print("H1 : Les variables Âge et panier moyen ne sont pas indépendants")
    print("p-value :",p)
    print("Corrélation :", corr)
# Out:
# H1 : Les variables Âge et panier moyen ne sont pas indépendants
# p-value : 2.6792370980385305e-47
# Corrélation : -0.360655299919713

# %% [markdown]
# La corrélation entre les deux variables est négative comme nous pouvons le voir sur le graphique ci-dessus.
# Nous pouvons en conclure que plus l'âge augmente, plus le panier moyen baisse

# %% [markdown]
# ## Lien entre âge et catégorie d'achat

# %% [markdown]
# L'âge des clients est-il différent en fonction de la catégorie d'achat ?
# - H0 : La moyenne des âges des clients est identique quelque soit la catégorie d'achat
# - H1 : Au moins l'une des moyennes des âges des clients est différentes en fonction de la catégorie d'achat
#
# Condition de validation du test ANOVA :
# - Type des variables (Qualitative et Quantitative) : Categ (quali) et Âge (quanti continue)
# - Independence : On utilise la fonction sample() avec 1500 entrées
# - Normalité : On vérifie la normalité de la variable Âge. Pour cela, on utilise le test de Shapiro
# - Egalité des variances : Avec par exemple le test be bartlett

# %%
#Affichage du boxplot 

plt.figure(figsize=(10,6))
plt.title("Moyenne des âges en fonction de la catégorie")
sns.boxplot(data=sample_df, x="Âge", y="categ", orient="h",showfliers=False, showmeans=True)
plt.show()

# %% [markdown]
# Moyenne proche entre les catégories 0 et 1

# %% [markdown]
# Dans un test ANOVA, on cherche à déterminer si les moyennes sont significativement différentes.
#
# H0 : Les moyennes de chaque groupe sont égales si p-value > 5% </br>
# H1 : Les moyennes de chaque groupe ne sont pas toutes égales si p-value < 5%

# %%
# Test de normalité
stat, p = shapiro(sample_df["Âge"])
if p > 0.05:
    print("H0 : Les données ne semblent pas respecter une loi normale")
    print("p-value :",p)
else:
    print("H1 : Les données semblent respecter une loie normale")
    print("p-value :",p)
# Out:
# H1 : Les données semblent respecter une loie normale
# p-value : 1.773252357769445e-16

# %%
# Test des variances
sample_df.groupby("categ")['Âge'].agg('var')
# Out:
# categ
# 0.0    132.814464
# 1.0    239.478318
# 2.0     73.325962
# Name: Âge, dtype: float64

# %%
#Test de bartlett, test sur la variance

from scipy.stats import bartlett

stat, p = bartlett(sample_df.Âge[sample_df.categ == 0.0],
        sample_df.Âge[sample_df.categ == 1.0],
        sample_df.Âge[sample_df.categ == 2.0])

if p > 0.05:
    print('H0: les variances sont égales')
    print("p-value :",p)
else:
    print('H1: les variances ne sont pas égales')
    print("p-value :",p)
# Out:
# H1: les variances ne sont pas égales
# p-value : 5.5291467862346125e-17

# %% [markdown]
# Le test de bartlett n'étant pas concluant, nous devons utiliser le test de Welch ANOVA

# %%
# Test Welch ANOVA

stat, p = ttest_ind(sample_df["Âge"], sample_df["categ"])

if p > 0.05:
    print("H0: les moyennes des échantillons sont égales")
    print("pvalue : ",p)
else:
    print("H1: une ou plus des moyennes des échantillons sont inégales")
    print("pvalue : ",p)
# Out:
# H1: une ou plus des moyennes des échantillons sont inégales
# pvalue :  0.0

# %% [markdown]
# Pour conclure, si au moins l'une des moyennes des échantillons sont inégales, cela signifique qu'il existe une corrélation entre l'âge du client et la catégorie des livres achetés
